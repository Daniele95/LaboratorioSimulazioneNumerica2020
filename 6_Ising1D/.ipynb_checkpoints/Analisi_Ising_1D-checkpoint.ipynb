# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

M=100000              # Total number of throws
N=200                 # Number of blocks
L=int(M/N)

x = np.arange(N)      # [0,1,2,...,N-1]

x*=L # Number of throws = block * (Number of throws in each block)


chi = np.loadtxt(fname = "output.chi.0", usecols=(1))
ene = np.loadtxt(fname = "output.ene.0", usecols=(1))
mag = np.loadtxt(fname = "output.mag.0", usecols=(1))
heat = np.loadtxt(fname = "output.heat.0", usecols=(1))


sum_prog = np.loadtxt(fname = "output.chi.0", usecols=(2))
err_prog = np.loadtxt(fname = "output.chi.0", usecols=(3))



medie = np.loadtxt(fname = "output.ene.0", usecols=(1))

#print( np.average(medie[100:]))

#plt.errorbar(x,chi)
plt.errorbar(x,ene)
plt.errorbar(x,mag)
plt.errorbar(x,heat)

plt.xlabel('#throws')
plt.ylabel('')
plt.grid(True)
plt.autoscale(enable=True, axis='both', tight=None)
plt.show()

# %%
np.average(chi)
# Out:
# 78.63031249999999
